# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import re

from datetime import datetime
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# 지수 표기법을 10진수로 변경
pd.set_option('display.float_format', '{:.2f}'.format)

import platform

system = platform.system()

if system == 'Windows':
    plt.rcParams['font.family'] = 'Malgun Gothic'
    
else:
    # !apt-get -y install fonts-nanum
    # !fc-cache -fv
    # !rm ~/.cache/matplotlib -rf

    plt.rcParams['font.family'] = 'NanumBarunGothic'

# minus 기호 깨짐 방지
plt.rcParams['axes.unicode_minus'] = False

# %%
df = pd.read_csv("MACD_DIVE_results_20250225_093013.csv")

# %%
df.query("trades_per_day > 1 & win_rate > 60").sort_values('total_trades', ascending=False).head(50)
# Out:
#      FAST_LENGTH  SLOW_LENGTH  SIGNAL_LENGTH  HISTOGRAM_UPPER_LIMIT  \
# 145           10           21             16                     50
# 415           10           26             12                     50
# 475           10           26             14                     70
# 730           10           31             10                     50
# 205           10           21             18                     70
# 410           10           26             12                     50
# 100           10           21             14                     50
# 725           10           31             10                     50
# 771           10           31             12                     50
# 146           10           21             16                     50
# 837           10           31             14                     70
# 805           10           31             12                     90
# 370           10           26             10                     50
# ...

# %%
df_super = pd.read_csv("SUPERTREND_results_20250225_073931.csv")
# Out:
# Empty DataFrame
# Columns: [ATR_PERIOD, ATR_MULTIPLIER, ADX_LENGTH, DI_DIFFERENCE_FILTER, DI_DIFFERENCE_LOOKBACK_PERIOD, trades_per_day, win_rate, total_trades, wins, losses, final_capital, profit_percentage]
# Index: []

# %%
df_super.query("profit_percentage > 0").sort_values('total_trades', ascending=False).head(50)
# Out:
#      ATR_PERIOD  ATR_MULTIPLIER  ADX_LENGTH  DI_DIFFERENCE_FILTER  \
# 231          30               5          10                     7
# 251          30               5          11                     6
# 325          30               5          14                     6
# 256          30               5          11                     7
# 232          30               5          10                     7
# 252          30               5          11                     6
# 228          30               5          10                     6
# 450          30               6          10                     6
# 277          30               5          12                     6
# 475          30               6          11                     6
# 229          30               5          10                     6
# 253          30               5          11                     6
# 237          30               5          10                     8
# ...

# %%
df_super.sort_values('win_rate', ascending=False).head(50)
# Out:
#      ATR_PERIOD  ATR_MULTIPLIER  ADX_LENGTH  DI_DIFFERENCE_FILTER  \
# 207          30               4          18                     7
# 182          30               4          17                     7
# 178          30               4          17                     6
# 550          30               6          14                     6
# 39           30               4          11                     8
# 657          30               6          18                     7
# 530          30               6          13                     7
# 628          30               6          17                     6
# 129          30               4          15                     6
# 475          30               6          11                     6
# 629          30               6          17                     6
# 582          30               6          15                     7
# 254          30               5          11                     6
# ...
